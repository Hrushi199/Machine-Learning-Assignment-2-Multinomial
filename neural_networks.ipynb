# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import random
import os
import optuna
from optuna.samplers import TPESampler
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import f1_score

# ============================================================================
# 1. CONFIGURATION & SEEDING
# ============================================================================
def seed_everything(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

SEED = 42
seed_everything(SEED)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"✅ Processing on: {DEVICE}")

# Fixed Settings
BATCH_SIZE = 64
N_TRIALS = 600  # How many Optuna trials to run

# ============================================================================
# 2. DATA LOADING & ENGINEERING
# ============================================================================
def create_advanced_features(df):
    df = df.copy()
    activity_cols = ['hobby_engagement_level', 'physical_activity_index', 
                     'creative_expression_index', 'altruism_score']
    df['total_activity'] = df[activity_cols].sum(axis=1)
    df['support_guidance_combo'] = df['support_environment_score'] * (df['external_guidance_usage'] + 1)
    df['focus_efficiency'] = df['focus_intensity'] / (df['consistency_score'] + 1)
    df['consistency_gap'] = 30 - df['consistency_score']
    df['focus_sq'] = df['focus_intensity'] ** 2
    df['focus_X_consistency'] = df['focus_intensity'] * df['consistency_score']
    df['low_focus_high_consist'] = ((df['focus_intensity'] < 5) & (df['consistency_score'] > 24)).astype(int)
    return df

try:
    train_df = pd.read_csv('train.csv')
    test_df = pd.read_csv('test.csv')
except FileNotFoundError:
    raise FileNotFoundError("❌ Upload train.csv and test.csv!")

train_df = create_advanced_features(train_df)
test_df = create_advanced_features(test_df)

X = train_df.drop(['participant_id', 'personality_cluster'], axis=1)
y = train_df['personality_cluster']
test_ids = test_df['participant_id']
X_test = test_df.drop(['participant_id'], axis=1)

# ============================================================================
# 3. PREPROCESSING (EMBEDDINGS + SCALING)
# ============================================================================
cat_cols = [
    'identity_code', 'cultural_background', 'age_group', 
    'upbringing_influence', 'support_environment_score', 
    'hobby_engagement_level', 'physical_activity_index',
    'creative_expression_index', 'altruism_score',
    'low_focus_high_consist'
]

cat_dims = []
for col in cat_cols:
    le = LabelEncoder()
    full_data = pd.concat([X[col], X_test[col]], axis=0).astype(str)
    le.fit(full_data)
    X[col] = le.transform(X[col].astype(str))
    X_test[col] = le.transform(X_test[col].astype(str))
    num_classes = len(le.classes_)
    emb_dim = min(50, (num_classes + 1) // 2)
    cat_dims.append((num_classes, emb_dim))

num_cols = [c for c in X.columns if c not in cat_cols]
scaler = StandardScaler()
X[num_cols] = scaler.fit_transform(X[num_cols])
X_test[num_cols] = scaler.transform(X_test[num_cols])

X_cat = X[cat_cols].values.astype(np.int64)
X_num = X[num_cols].values.astype(np.float32)
X_test_cat = X_test[cat_cols].values.astype(np.int64)
X_test_num = X_test[num_cols].values.astype(np.float32)

target_le = LabelEncoder()
y_encoded = target_le.fit_transform(y)
num_classes_target = len(target_le.classes_)

class_weights = compute_class_weight('balanced', classes=np.unique(y_encoded), y=y_encoded)
class_weights_tensor = torch.tensor(class_weights, dtype=torch.float).to(DEVICE)

# ============================================================================
# 4. DYNAMIC MODEL ARCHITECTURE
# ============================================================================
class AdvancedTabularDataset(Dataset):
    def __init__(self, x_cat, x_num, y=None):
        self.x_cat = torch.tensor(x_cat, dtype=torch.long)
        self.x_num = torch.tensor(x_num, dtype=torch.float)
        self.y = torch.tensor(y, dtype=torch.long) if y is not None else None
    def __len__(self): return len(self.x_cat)
    def __getitem__(self, idx):
        if self.y is not None: return self.x_cat[idx], self.x_num[idx], self.y[idx]
        return self.x_cat[idx], self.x_num[idx]

class DynamicTabularModel(nn.Module):
    def __init__(self, cat_dims, num_dim, output_dim, 
                 l1_size, l2_size, l3_size, 
                 emb_dropout, hidden_dropout):
        super(DynamicTabularModel, self).__init__()
        
        self.embeddings = nn.ModuleList([
            nn.Embedding(n, d) for n, d in cat_dims
        ])
        self.emb_dropout = nn.Dropout(emb_dropout)
        total_emb_dim = sum([d for _, d in cat_dims])
        
        input_dim = total_emb_dim + num_dim
        self.bn0 = nn.BatchNorm1d(num_dim)
        
        # Dynamic Layers based on Optuna
        self.fc1 = nn.Linear(input_dim, l1_size)
        self.bn1 = nn.BatchNorm1d(l1_size)
        self.act1 = nn.GELU()
        self.drop1 = nn.Dropout(hidden_dropout)
        
        self.fc2 = nn.Linear(l1_size, l2_size)
        self.bn2 = nn.BatchNorm1d(l2_size)
        self.act2 = nn.GELU()
        self.drop2 = nn.Dropout(hidden_dropout)
        
        self.fc3 = nn.Linear(l2_size, l3_size)
        self.bn3 = nn.BatchNorm1d(l3_size)
        self.act3 = nn.GELU()
        self.drop3 = nn.Dropout(hidden_dropout / 2)
        
        self.output = nn.Linear(l3_size, output_dim)
        
    def forward(self, x_cat, x_num):
        emb_list = [emb(x_cat[:, i]) for i, emb in enumerate(self.embeddings)]
        x_emb = self.emb_dropout(torch.cat(emb_list, dim=1))
        x_num = self.bn0(x_num)
        x = torch.cat([x_emb, x_num], dim=1)
        
        x = self.drop1(self.act1(self.bn1(self.fc1(x))))
        x = self.drop2(self.act2(self.bn2(self.fc2(x))))
        x = self.drop3(self.act3(self.bn3(self.fc3(x))))
        return self.output(x)

# ============================================================================
# 5. OPTUNA OBJECTIVE
# ============================================================================
print(f"--- Starting Optuna Tuning ({N_TRIALS} Trials) ---")

def objective(trial):
    # 1. Suggest Hyperparameters
    l1_size = trial.suggest_int('l1_size', 128, 512)
    l2_size = trial.suggest_int('l2_size', 64, 256)
    l3_size = trial.suggest_int('l3_size', 32, 128)
    emb_dropout = trial.suggest_float('emb_dropout', 0.1, 0.5)
    hidden_dropout = trial.suggest_float('hidden_dropout', 0.1, 0.5)
    lr = trial.suggest_float('lr', 1e-4, 1e-2, log=True)
    weight_decay = trial.suggest_float('weight_decay', 1e-6, 1e-3, log=True)
    
    # 2. Training Loop (Using 3-Fold CV for Speed during tuning)
    skf_tune = StratifiedKFold(n_splits=3, shuffle=True, random_state=SEED)
    scores = []
    
    for train_idx, val_idx in skf_tune.split(X_num, y_encoded):
        train_ds = AdvancedTabularDataset(X_cat[train_idx], X_num[train_idx], y_encoded[train_idx])
        val_ds = AdvancedTabularDataset(X_cat[val_idx], X_num[val_idx], y_encoded[val_idx])
        
        train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)
        val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE*2, shuffle=False, num_workers=0)
        
        model = DynamicTabularModel(cat_dims, X_num.shape[1], num_classes_target,
                                    l1_size, l2_size, l3_size, emb_dropout, hidden_dropout).to(DEVICE)
        
        criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)
        optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
        
        # Short training for tuning (25 Epochs)
        for epoch in range(25):
            model.train()
            for c, n, y_batch in train_loader:
                c, n, y_batch = c.to(DEVICE), n.to(DEVICE), y_batch.to(DEVICE)
                optimizer.zero_grad()
                loss = criterion(model(c, n), y_batch)
                loss.backward()
                optimizer.step()
                
        # Validate
        model.eval()
        preds, labels = [], []
        with torch.no_grad():
            for c, n, y_batch in val_loader:
                c, n = c.to(DEVICE), n.to(DEVICE)
                p = torch.argmax(model(c, n), dim=1)
                preds.extend(p.cpu().numpy())
                labels.extend(y_batch.numpy())
        
        scores.append(f1_score(labels, preds, average='macro'))
        
        # Pruning (Optional: stop bad trials early)
        trial.report(scores[-1], 0)
        if trial.should_prune():
            raise optuna.exceptions.TrialPruned()
            
    return np.mean(scores)

# Run Optimization
sampler = TPESampler(seed=SEED) # REPRODUCIBLE SAMPLER
study = optuna.create_study(direction="maximize", sampler=sampler)
study.optimize(objective, n_trials=N_TRIALS)

print("\n✅ BEST PARAMS FOUND:")
print(study.best_params)
best_p = study.best_params

# ============================================================================
# 6. FINAL TRAINING (FULL 5-FOLD with BEST PARAMS)
# ============================================================================
print("\n--- Retraining Final Model with Best Params (5 Folds) ---")

skf_final = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
test_probs_sum = np.zeros((len(X_test), num_classes_target))
final_f1_scores = []

# Final Model Settings (More Epochs for final convergence)
FINAL_EPOCHS = 50 

for fold, (train_idx, val_idx) in enumerate(skf_final.split(X_num, y_encoded)):
    train_ds = AdvancedTabularDataset(X_cat[train_idx], X_num[train_idx], y_encoded[train_idx])
    val_ds = AdvancedTabularDataset(X_cat[val_idx], X_num[val_idx], y_encoded[val_idx])
    
    train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)
    val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE*2, shuffle=False, num_workers=0)
    
    model = DynamicTabularModel(
        cat_dims, X_num.shape[1], num_classes_target,
        best_p['l1_size'], best_p['l2_size'], best_p['l3_size'],
        best_p['emb_dropout'], best_p['hidden_dropout']
    ).to(DEVICE)
    
    criterion = nn.CrossEntropyLoss(weight=class_weights_tensor, label_smoothing=0.1)
    optimizer = optim.AdamW(model.parameters(), lr=best_p['lr'], weight_decay=best_p['weight_decay'])
    scheduler = optim.lr_scheduler.OneCycleLR(optimizer, max_lr=best_p['lr']*10, 
                                              steps_per_epoch=len(train_loader), epochs=FINAL_EPOCHS)
    
    best_val_f1 = 0
    best_state = None
    
    for epoch in range(FINAL_EPOCHS):
        model.train()
        for c, n, y_batch in train_loader:
            c, n, y_batch = c.to(DEVICE), n.to(DEVICE), y_batch.to(DEVICE)
            optimizer.zero_grad()
            loss = criterion(model(c, n), y_batch)
            loss.backward()
            optimizer.step()
            scheduler.step()
            
        # Validate
        model.eval()
        preds, labels = [], []
        with torch.no_grad():
            for c, n, y_batch in val_loader:
                c, n = c.to(DEVICE), n.to(DEVICE)
                p = torch.argmax(model(c, n), dim=1)
                preds.extend(p.cpu().numpy())
                labels.extend(y_batch.numpy())
        
        f1 = f1_score(labels, preds, average='macro')
        if f1 > best_val_f1:
            best_val_f1 = f1
            best_state = model.state_dict()
            
    print(f"Fold {fold+1} | Best F1: {best_val_f1:.4f}")
    final_f1_scores.append(best_val_f1)
    
    # Predict Test
    model.load_state_dict(best_state)
    model.eval()
    test_ds = AdvancedTabularDataset(X_test_cat, X_test_num)
    test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE*2, shuffle=False, num_workers=0)
    
    fold_probs = []
    with torch.no_grad():
        for c, n in test_loader:
            c, n = c.to(DEVICE), n.to(DEVICE)
            probs = torch.softmax(model(c, n), dim=1)
            fold_probs.append(probs.cpu().numpy())
    test_probs_sum += np.concatenate(fold_probs)

# ============================================================================
# 7. SAVING RESULTS
# ============================================================================
print(f"\n🏆 Final Average F1: {np.mean(final_f1_scores):.4f}")

avg_test_probs = test_probs_sum / 5

# Save Probs
prob_df = pd.DataFrame(avg_test_probs, columns=[f'prob_{i}' for i in range(num_classes_target)])
prob_df['participant_id'] = test_ids.values
prob_df.to_csv('nn_optuna_probs.csv', index=False)
print("✅ Saved 'nn_optuna_probs.csv'")

# Save Submission
final_indices = np.argmax(avg_test_probs, axis=1)
final_labels = target_le.inverse_transform(final_indices)
submission_df = pd.DataFrame({
    'participant_id': test_ids,
    'personality_cluster': final_labels
})
submission_df.to_csv('submission_600_nn_optuna.csv', index=False)
print("✅ Saved 'submission_600_nn_optuna.csv'")
# Out:
# [I 2025-11-23 17:05:13,708] A new study created in memory with name: no-name-5d84c06f-3cd8-4ee0-b4c5-d3cec8d00812
# ✅ Processing on: cuda
# --- Starting Optuna Tuning (600 Trials) ---
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:05:21,102] Trial 0 finished with value: 0.5999046190051752 and parameters: {'l1_size': 272, 'l2_size': 247, 'l3_size': 103, 'emb_dropout': 0.3394633936788146, 'hidden_dropout': 0.1624074561769746, 'lr': 0.00020511104188433984, 'weight_decay': 1.493656855461763e-06}. Best is trial 0 with value: 0.5999046190051752.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:05:27,873] Trial 1 finished with value: 0.571372800237618 and parameters: {'l1_size': 461, 'l2_size': 180, 'l3_size': 100, 'emb_dropout': 0.10823379771832098, 'hidden_dropout': 0.4879639408647978, 'lr': 0.004622589001020831, 'weight_decay': 4.335281794951567e-06}. Best is trial 0 with value: 0.5999046190051752.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:05:34,334] Trial 2 finished with value: 0.6071613298309125 and parameters: {'l1_size': 198, 'l2_size': 99, 'l3_size': 61, 'emb_dropout': 0.3099025726528951, 'hidden_dropout': 0.2727780074568463, 'lr': 0.0003823475224675188, 'weight_decay': 6.847920095574779e-05}. Best is trial 2 with value: 0.6071613298309125.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:05:40,631] Trial 3 finished with value: 0.5604617145457403 and parameters: {'l1_size': 181, 'l2_size': 120, 'l3_size': 67, 'emb_dropout': 0.28242799368681437, 'hidden_dropout': 0.41407038455720546, 'lr': 0.00025081156860452336, 'weight_decay': 3.489018845491386e-05}. Best is trial 2 with value: 0.6071613298309125.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:05:46,737] Trial 4 finished with value: 0.5278465390401877 and parameters: {'l1_size': 356, 'l2_size': 72, 'l3_size': 90, 'emb_dropout': 0.16820964947491662, 'hidden_dropout': 0.12602063719411183, 'lr': 0.007902619549708232, 'weight_decay': 0.0007886714129990489}. Best is trial 2 with value: 0.6071613298309125.
# [I 2025-11-23 17:05:48,745] Trial 5 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:05:54,732] Trial 6 finished with value: 0.5914468380780614 and parameters: {'l1_size': 141, 'l2_size': 239, 'l3_size': 57, 'emb_dropout': 0.36500891374159283, 'hidden_dropout': 0.2246844304357644, 'lr': 0.001096821720752952, 'weight_decay': 4.366473592979636e-05}. Best is trial 2 with value: 0.6071613298309125.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:06:00,847] Trial 7 finished with value: 0.6186945195823362 and parameters: {'l1_size': 199, 'l2_size': 251, 'l3_size': 107, 'emb_dropout': 0.4757995766256756, 'hidden_dropout': 0.4579309401710595, 'lr': 0.0015696396388661157, 'weight_decay': 0.0005829384542994739}. Best is trial 7 with value: 0.6186945195823362.
# [I 2025-11-23 17:06:02,916] Trial 8 pruned.
# [I 2025-11-23 17:06:04,961] Trial 9 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:06:10,803] Trial 10 finished with value: 0.5987354982645744 and parameters: {'l1_size': 325, 'l2_size': 199, 'l3_size': 126, 'emb_dropout': 0.48205597479057966, 'hidden_dropout': 0.36074662031127125, 'lr': 0.0014138916628611991, 'weight_decay': 0.0001552746952753857}. Best is trial 7 with value: 0.6186945195823362.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:06:16,909] Trial 11 finished with value: 0.5991023898974636 and parameters: {'l1_size': 232, 'l2_size': 156, 'l3_size': 125, 'emb_dropout': 0.49708244605598284, 'hidden_dropout': 0.33508933664958496, 'lr': 0.0006002442815495965, 'weight_decay': 0.00011041330465267085}. Best is trial 7 with value: 0.6186945195823362.
# [I 2025-11-23 17:06:18,940] Trial 12 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:06:25,027] Trial 13 finished with value: 0.6068649363595097 and parameters: {'l1_size': 393, 'l2_size': 154, 'l3_size': 108, 'emb_dropout': 0.42837964967997805, 'hidden_dropout': 0.49611318871547727, 'lr': 0.0005307110251538382, 'weight_decay': 0.00035800873318653253}. Best is trial 7 with value: 0.6186945195823362.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:06:31,045] Trial 14 finished with value: 0.5920686400757628 and parameters: {'l1_size': 229, 'l2_size': 64, 'l3_size': 74, 'emb_dropout': 0.26676984333100023, 'hidden_dropout': 0.33329086158653104, 'lr': 0.002222732171469652, 'weight_decay': 0.00011606159532098588}. Best is trial 7 with value: 0.6186945195823362.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:06:36,975] Trial 15 finished with value: 0.5915186795803148 and parameters: {'l1_size': 276, 'l2_size': 222, 'l3_size': 51, 'emb_dropout': 0.4247980269689908, 'hidden_dropout': 0.4085172062987911, 'lr': 0.0006333672200117979, 'weight_decay': 1.3359622807599408e-05}. Best is trial 7 with value: 0.6186945195823362.
# [I 2025-11-23 17:06:38,941] Trial 16 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:06:44,806] Trial 17 finished with value: 0.5934503044514691 and parameters: {'l1_size': 192, 'l2_size': 95, 'l3_size': 93, 'emb_dropout': 0.34068493919437415, 'hidden_dropout': 0.36509212338240876, 'lr': 0.0019104721873984506, 'weight_decay': 7.769723959778746e-05}. Best is trial 7 with value: 0.6186945195823362.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:06:51,143] Trial 18 finished with value: 0.6009622980138315 and parameters: {'l1_size': 314, 'l2_size': 136, 'l3_size': 77, 'emb_dropout': 0.4551097883344568, 'hidden_dropout': 0.45141860322314553, 'lr': 0.003965274438420915, 'weight_decay': 1.8790033312090087e-05}. Best is trial 7 with value: 0.6186945195823362.
# [I 2025-11-23 17:06:53,202] Trial 19 pruned.
# [I 2025-11-23 17:06:55,210] Trial 20 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:07:01,091] Trial 21 finished with value: 0.5924617857420822 and parameters: {'l1_size': 382, 'l2_size': 156, 'l3_size': 112, 'emb_dropout': 0.4363436803890315, 'hidden_dropout': 0.49765184738778184, 'lr': 0.0004631790636868316, 'weight_decay': 0.0004350131522394377}. Best is trial 7 with value: 0.6186945195823362.
# [I 2025-11-23 17:07:02,927] Trial 22 pruned.
# [I 2025-11-23 17:07:04,797] Trial 23 pruned.
# [I 2025-11-23 17:07:06,792] Trial 24 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:07:12,999] Trial 25 finished with value: 0.6038265065933158 and parameters: {'l1_size': 238, 'l2_size': 204, 'l3_size': 117, 'emb_dropout': 0.47194593427606585, 'hidden_dropout': 0.3183722694989315, 'lr': 0.000535762399279508, 'weight_decay': 0.0002621986575570208}. Best is trial 7 with value: 0.6186945195823362.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:07:19,113] Trial 26 finished with value: 0.6261513275085828 and parameters: {'l1_size': 352, 'l2_size': 165, 'l3_size': 96, 'emb_dropout': 0.49898793139238923, 'hidden_dropout': 0.4662528627664207, 'lr': 0.0009290072205304433, 'weight_decay': 0.0005051820468833858}. Best is trial 26 with value: 0.6261513275085828.
# [I 2025-11-23 17:07:21,194] Trial 27 pruned.
# [I 2025-11-23 17:07:23,159] Trial 28 pruned.
# [I 2025-11-23 17:07:25,134] Trial 29 pruned.
# [I 2025-11-23 17:07:27,101] Trial 30 pruned.
# [I 2025-11-23 17:07:29,118] Trial 31 pruned.
# [I 2025-11-23 17:07:31,167] Trial 32 pruned.
# [I 2025-11-23 17:07:33,198] Trial 33 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:07:39,311] Trial 34 finished with value: 0.6203803967368459 and parameters: {'l1_size': 296, 'l2_size': 147, 'l3_size': 99, 'emb_dropout': 0.4777050672361482, 'hidden_dropout': 0.4960313832328808, 'lr': 0.0006489325129683808, 'weight_decay': 0.00014815249203435632}. Best is trial 26 with value: 0.6261513275085828.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:07:45,467] Trial 35 finished with value: 0.6049706633714167 and parameters: {'l1_size': 293, 'l2_size': 118, 'l3_size': 88, 'emb_dropout': 0.48016922601515505, 'hidden_dropout': 0.40617503721538395, 'lr': 0.0030093725637813473, 'weight_decay': 0.00014168252173644738}. Best is trial 26 with value: 0.6261513275085828.
# [I 2025-11-23 17:07:47,369] Trial 36 pruned.
# [I 2025-11-23 17:07:49,244] Trial 37 pruned.
# [I 2025-11-23 17:07:51,186] Trial 38 pruned.
# [I 2025-11-23 17:07:53,149] Trial 39 pruned.
# [I 2025-11-23 17:07:55,231] Trial 40 pruned.
# [I 2025-11-23 17:07:57,317] Trial 41 pruned.
# [I 2025-11-23 17:07:59,396] Trial 42 pruned.
# [I 2025-11-23 17:08:01,492] Trial 43 pruned.
# [I 2025-11-23 17:08:03,638] Trial 44 pruned.
# [I 2025-11-23 17:08:05,780] Trial 45 pruned.
# [I 2025-11-23 17:08:07,748] Trial 46 pruned.
# [I 2025-11-23 17:08:09,592] Trial 47 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:08:15,542] Trial 48 finished with value: 0.6012598971566601 and parameters: {'l1_size': 280, 'l2_size': 173, 'l3_size': 113, 'emb_dropout': 0.48901306450120874, 'hidden_dropout': 0.3907681074175666, 'lr': 0.0018998203085547854, 'weight_decay': 0.00044978878344443916}. Best is trial 26 with value: 0.6261513275085828.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:08:21,608] Trial 49 finished with value: 0.6026001480377922 and parameters: {'l1_size': 415, 'l2_size': 86, 'l3_size': 105, 'emb_dropout': 0.4155967509270261, 'hidden_dropout': 0.3558048605179972, 'lr': 0.0006372762001644175, 'weight_decay': 0.0007412559707187588}. Best is trial 26 with value: 0.6261513275085828.
# [I 2025-11-23 17:08:23,624] Trial 50 pruned.
# [I 2025-11-23 17:08:25,621] Trial 51 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:08:31,648] Trial 52 finished with value: 0.6165720162531216 and parameters: {'l1_size': 244, 'l2_size': 122, 'l3_size': 89, 'emb_dropout': 0.48309456957198144, 'hidden_dropout': 0.46118288081033293, 'lr': 0.0053201412489507814, 'weight_decay': 0.00012341206979350048}. Best is trial 26 with value: 0.6261513275085828.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:08:37,622] Trial 53 finished with value: 0.6139515398675117 and parameters: {'l1_size': 247, 'l2_size': 127, 'l3_size': 78, 'emb_dropout': 0.4478030220904763, 'hidden_dropout': 0.4620350216728765, 'lr': 0.006608152778434199, 'weight_decay': 0.00010489592013283832}. Best is trial 26 with value: 0.6261513275085828.
# [I 2025-11-23 17:08:39,598] Trial 54 pruned.
# [I 2025-11-23 17:08:41,549] Trial 55 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:08:47,695] Trial 56 finished with value: 0.6233272987570613 and parameters: {'l1_size': 268, 'l2_size': 123, 'l3_size': 79, 'emb_dropout': 0.44183827317755275, 'hidden_dropout': 0.4493586863052084, 'lr': 0.004942871787219177, 'weight_decay': 6.121143418756346e-05}. Best is trial 26 with value: 0.6261513275085828.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:08:53,877] Trial 57 finished with value: 0.6055212542780936 and parameters: {'l1_size': 268, 'l2_size': 124, 'l3_size': 80, 'emb_dropout': 0.4432965506268651, 'hidden_dropout': 0.44315639268764107, 'lr': 0.004091035033181667, 'weight_decay': 0.00010590577310286459}. Best is trial 26 with value: 0.6261513275085828.
# [I 2025-11-23 17:08:55,758] Trial 58 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:09:01,641] Trial 59 finished with value: 0.6011686566827706 and parameters: {'l1_size': 226, 'l2_size': 144, 'l3_size': 91, 'emb_dropout': 0.4858609112088788, 'hidden_dropout': 0.45805611923381817, 'lr': 0.006241210047290158, 'weight_decay': 6.886341382260877e-05}. Best is trial 26 with value: 0.6261513275085828.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:09:07,724] Trial 60 finished with value: 0.6051709870477434 and parameters: {'l1_size': 276, 'l2_size': 139, 'l3_size': 77, 'emb_dropout': 0.4373092699049058, 'hidden_dropout': 0.3973450870900651, 'lr': 0.004565696688209628, 'weight_decay': 0.00012969006504950253}. Best is trial 26 with value: 0.6261513275085828.
# [I 2025-11-23 17:09:09,820] Trial 61 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:09:16,145] Trial 62 finished with value: 0.6127020057566056 and parameters: {'l1_size': 307, 'l2_size': 122, 'l3_size': 55, 'emb_dropout': 0.4995508310843364, 'hidden_dropout': 0.4859999648097917, 'lr': 0.005404192978545441, 'weight_decay': 5.744838889999055e-05}. Best is trial 26 with value: 0.6261513275085828.
# [I 2025-11-23 17:09:18,068] Trial 63 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:09:24,288] Trial 64 finished with value: 0.6078892000831873 and parameters: {'l1_size': 337, 'l2_size': 132, 'l3_size': 35, 'emb_dropout': 0.49991797444167063, 'hidden_dropout': 0.46504622654572614, 'lr': 0.007401830752066967, 'weight_decay': 7.905602950548976e-05}. Best is trial 26 with value: 0.6261513275085828.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:09:30,414] Trial 65 finished with value: 0.6099024845758529 and parameters: {'l1_size': 262, 'l2_size': 159, 'l3_size': 43, 'emb_dropout': 0.47261400759455324, 'hidden_dropout': 0.4495894352250952, 'lr': 0.006310295508742413, 'weight_decay': 3.703178701816575e-05}. Best is trial 26 with value: 0.6261513275085828.
# [I 2025-11-23 17:09:32,847] Trial 66 pruned.
# [I 2025-11-23 17:09:35,491] Trial 67 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:09:42,725] Trial 68 finished with value: 0.6143670083698775 and parameters: {'l1_size': 297, 'l2_size': 148, 'l3_size': 82, 'emb_dropout': 0.479103819375355, 'hidden_dropout': 0.4387106803155003, 'lr': 0.0024226424558031743, 'weight_decay': 6.101619534270661e-05}. Best is trial 26 with value: 0.6261513275085828.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:09:50,026] Trial 69 finished with value: 0.6115353571405336 and parameters: {'l1_size': 266, 'l2_size': 144, 'l3_size': 80, 'emb_dropout': 0.4331273080079783, 'hidden_dropout': 0.4390324302443113, 'lr': 0.002265816151540844, 'weight_decay': 0.00010347333475917324}. Best is trial 26 with value: 0.6261513275085828.
# [I 2025-11-23 17:09:52,509] Trial 70 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:09:59,752] Trial 71 finished with value: 0.6184476458110878 and parameters: {'l1_size': 324, 'l2_size': 113, 'l3_size': 98, 'emb_dropout': 0.4800783628628509, 'hidden_dropout': 0.4547642690419475, 'lr': 0.005263998701167374, 'weight_decay': 5.902613091751513e-05}. Best is trial 26 with value: 0.6261513275085828.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:10:07,148] Trial 72 finished with value: 0.6158163585597883 and parameters: {'l1_size': 324, 'l2_size': 114, 'l3_size': 97, 'emb_dropout': 0.47843929432508053, 'hidden_dropout': 0.4536761091931136, 'lr': 0.0018464852478702867, 'weight_decay': 8.70038610450743e-05}. Best is trial 26 with value: 0.6261513275085828.
# [I 2025-11-23 17:10:09,498] Trial 73 pruned.
# [I 2025-11-23 17:10:11,848] Trial 74 pruned.
# [I 2025-11-23 17:10:14,305] Trial 75 pruned.
# [I 2025-11-23 17:10:16,875] Trial 76 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:10:24,305] Trial 77 finished with value: 0.6183252696917255 and parameters: {'l1_size': 295, 'l2_size': 106, 'l3_size': 88, 'emb_dropout': 0.4908848393661436, 'hidden_dropout': 0.45303615053946755, 'lr': 0.002075241194427998, 'weight_decay': 2.5008750234023335e-05}. Best is trial 26 with value: 0.6261513275085828.
# [I 2025-11-23 17:10:26,805] Trial 78 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:10:34,859] Trial 79 finished with value: 0.6134860203582743 and parameters: {'l1_size': 311, 'l2_size': 111, 'l3_size': 95, 'emb_dropout': 0.46713026192842827, 'hidden_dropout': 0.45410951599864763, 'lr': 0.0007556863908089867, 'weight_decay': 0.0003226016712069564}. Best is trial 26 with value: 0.6261513275085828.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:10:43,141] Trial 80 finished with value: 0.6152353613671847 and parameters: {'l1_size': 286, 'l2_size': 92, 'l3_size': 88, 'emb_dropout': 0.32447167066342797, 'hidden_dropout': 0.48415111759566, 'lr': 0.0008730048981948461, 'weight_decay': 1.758539878991514e-05}. Best is trial 26 with value: 0.6261513275085828.
# [I 2025-11-23 17:10:46,022] Trial 81 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:10:53,665] Trial 82 finished with value: 0.6162236833559266 and parameters: {'l1_size': 318, 'l2_size': 97, 'l3_size': 86, 'emb_dropout': 0.4894400383593515, 'hidden_dropout': 0.4869577103118352, 'lr': 0.0010148312570214123, 'weight_decay': 5.845752679564491e-06}. Best is trial 26 with value: 0.6261513275085828.
# [I 2025-11-23 17:10:56,066] Trial 83 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:11:03,360] Trial 84 finished with value: 0.6220716135533589 and parameters: {'l1_size': 327, 'l2_size': 81, 'l3_size': 100, 'emb_dropout': 0.4604892794479065, 'hidden_dropout': 0.488309045363996, 'lr': 0.001691420896721683, 'weight_decay': 9.089416567174661e-06}. Best is trial 26 with value: 0.6261513275085828.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:11:10,624] Trial 85 finished with value: 0.6115950062793091 and parameters: {'l1_size': 297, 'l2_size': 78, 'l3_size': 109, 'emb_dropout': 0.45890640107151237, 'hidden_dropout': 0.49008506815141883, 'lr': 0.0013794762002188833, 'weight_decay': 4.779259483343946e-06}. Best is trial 26 with value: 0.6261513275085828.
# [I 2025-11-23 17:11:13,156] Trial 86 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:11:20,653] Trial 87 finished with value: 0.610349044096458 and parameters: {'l1_size': 315, 'l2_size': 107, 'l3_size': 114, 'emb_dropout': 0.4675456518911982, 'hidden_dropout': 0.47414720591981746, 'lr': 0.001636667773389516, 'weight_decay': 6.981943653507562e-06}. Best is trial 26 with value: 0.6261513275085828.
# [I 2025-11-23 17:11:23,101] Trial 88 pruned.
# [I 2025-11-23 17:11:25,527] Trial 89 pruned.
# [I 2025-11-23 17:11:27,947] Trial 90 pruned.
# [I 2025-11-23 17:11:30,380] Trial 91 pruned.
# [I 2025-11-23 17:11:32,829] Trial 92 pruned.
# [I 2025-11-23 17:11:35,237] Trial 93 pruned.
# [I 2025-11-23 17:11:37,887] Trial 94 pruned.
# [I 2025-11-23 17:11:40,395] Trial 95 pruned.
# [I 2025-11-23 17:11:42,796] Trial 96 pruned.
# [I 2025-11-23 17:11:45,233] Trial 97 pruned.
# [I 2025-11-23 17:11:47,687] Trial 98 pruned.
# [I 2025-11-23 17:11:50,081] Trial 99 pruned.
# [I 2025-11-23 17:11:52,654] Trial 100 pruned.
# [I 2025-11-23 17:11:55,073] Trial 101 pruned.
# [I 2025-11-23 17:11:57,507] Trial 102 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:12:04,807] Trial 103 finished with value: 0.6196889800963884 and parameters: {'l1_size': 272, 'l2_size': 99, 'l3_size': 75, 'emb_dropout': 0.47511320294677023, 'hidden_dropout': 0.4908219137704598, 'lr': 0.008973412208800243, 'weight_decay': 1.745436773909714e-05}. Best is trial 26 with value: 0.6261513275085828.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:12:12,083] Trial 104 finished with value: 0.6210408073522231 and parameters: {'l1_size': 271, 'l2_size': 88, 'l3_size': 75, 'emb_dropout': 0.47486265462937005, 'hidden_dropout': 0.4600882014840361, 'lr': 0.009340139567719364, 'weight_decay': 1.5545880443784232e-05}. Best is trial 26 with value: 0.6261513275085828.
# [I 2025-11-23 17:12:14,558] Trial 105 pruned.
# [I 2025-11-23 17:12:17,006] Trial 106 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:12:24,498] Trial 107 finished with value: 0.6176948211850057 and parameters: {'l1_size': 157, 'l2_size': 88, 'l3_size': 74, 'emb_dropout': 0.47109722304618795, 'hidden_dropout': 0.4611376714469412, 'lr': 0.007892799546074648, 'weight_decay': 2.648906706974144e-05}. Best is trial 26 with value: 0.6261513275085828.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:12:31,938] Trial 108 finished with value: 0.6285062077530171 and parameters: {'l1_size': 174, 'l2_size': 69, 'l3_size': 67, 'emb_dropout': 0.4705676940046093, 'hidden_dropout': 0.4600713508056729, 'lr': 0.008092755371287378, 'weight_decay': 2.9103804223837623e-05}. Best is trial 108 with value: 0.6285062077530171.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:12:39,464] Trial 109 finished with value: 0.6076295634983858 and parameters: {'l1_size': 150, 'l2_size': 70, 'l3_size': 65, 'emb_dropout': 0.4708067206389962, 'hidden_dropout': 0.43717881868146374, 'lr': 0.007884659013833001, 'weight_decay': 1.545460583769923e-05}. Best is trial 108 with value: 0.6285062077530171.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:12:46,917] Trial 110 finished with value: 0.62335283161545 and parameters: {'l1_size': 131, 'l2_size': 73, 'l3_size': 68, 'emb_dropout': 0.44181614591557394, 'hidden_dropout': 0.4437271839360385, 'lr': 0.008644917326944402, 'weight_decay': 2.9005147605725332e-05}. Best is trial 108 with value: 0.6285062077530171.
# [I 2025-11-23 17:12:49,407] Trial 111 pruned.
# [I 2025-11-23 17:12:51,809] Trial 112 pruned.
# [I 2025-11-23 17:12:54,273] Trial 113 pruned.
# [I 2025-11-23 17:12:56,682] Trial 114 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:13:03,846] Trial 115 finished with value: 0.6254888504380608 and parameters: {'l1_size': 128, 'l2_size': 74, 'l3_size': 74, 'emb_dropout': 0.4346374429161953, 'hidden_dropout': 0.49946907264196516, 'lr': 0.0071825081676030736, 'weight_decay': 4.994001601978298e-05}. Best is trial 108 with value: 0.6285062077530171.
# [I 2025-11-23 17:13:06,292] Trial 116 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:13:13,492] Trial 117 finished with value: 0.6339227462617446 and parameters: {'l1_size': 189, 'l2_size': 73, 'l3_size': 59, 'emb_dropout': 0.45346792236663874, 'hidden_dropout': 0.4769357885412404, 'lr': 0.008604238973909457, 'weight_decay': 4.158902485016973e-05}. Best is trial 117 with value: 0.6339227462617446.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:13:20,738] Trial 118 finished with value: 0.6067992663512761 and parameters: {'l1_size': 129, 'l2_size': 74, 'l3_size': 59, 'emb_dropout': 0.4512056468382643, 'hidden_dropout': 0.34355135698851696, 'lr': 0.007075916414487376, 'weight_decay': 4.5966750714976125e-05}. Best is trial 117 with value: 0.6339227462617446.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:13:27,892] Trial 119 finished with value: 0.6233771001831091 and parameters: {'l1_size': 170, 'l2_size': 67, 'l3_size': 68, 'emb_dropout': 0.44012082545530673, 'hidden_dropout': 0.47793724707590446, 'lr': 0.008840533721266204, 'weight_decay': 3.96510034116261e-05}. Best is trial 117 with value: 0.6339227462617446.
# [I 2025-11-23 17:13:30,270] Trial 120 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:13:37,399] Trial 121 finished with value: 0.6173712646966791 and parameters: {'l1_size': 189, 'l2_size': 81, 'l3_size': 68, 'emb_dropout': 0.4392322945255941, 'hidden_dropout': 0.4762045135490674, 'lr': 0.005820167621719487, 'weight_decay': 3.5390044408139816e-05}. Best is trial 117 with value: 0.6339227462617446.
# [I 2025-11-23 17:13:39,806] Trial 122 pruned.
# [I 2025-11-23 17:13:42,224] Trial 123 pruned.
# [I 2025-11-23 17:13:44,754] Trial 124 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:13:51,920] Trial 125 finished with value: 0.630480558277626 and parameters: {'l1_size': 162, 'l2_size': 83, 'l3_size': 58, 'emb_dropout': 0.46287251351830927, 'hidden_dropout': 0.4944304963504526, 'lr': 0.009114094190063043, 'weight_decay': 4.936855200102902e-05}. Best is trial 117 with value: 0.6339227462617446.
# [I 2025-11-23 17:13:54,480] Trial 126 pruned.
# [I 2025-11-23 17:13:56,962] Trial 127 pruned.
# [I 2025-11-23 17:13:59,362] Trial 128 pruned.
# [I 2025-11-23 17:14:01,778] Trial 129 pruned.
# [I 2025-11-23 17:14:04,260] Trial 130 pruned.
# [I 2025-11-23 17:14:06,789] Trial 131 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:14:13,967] Trial 132 finished with value: 0.6331364758069516 and parameters: {'l1_size': 177, 'l2_size': 85, 'l3_size': 76, 'emb_dropout': 0.47605714552021394, 'hidden_dropout': 0.48487475870291763, 'lr': 0.00929589818940088, 'weight_decay': 6.4500903749558e-05}. Best is trial 117 with value: 0.6339227462617446.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:14:21,324] Trial 133 finished with value: 0.6274447996212441 and parameters: {'l1_size': 174, 'l2_size': 85, 'l3_size': 76, 'emb_dropout': 0.43564649358954705, 'hidden_dropout': 0.4835879924255333, 'lr': 0.009213064905530578, 'weight_decay': 7.666454558776679e-05}. Best is trial 117 with value: 0.6339227462617446.
# [I 2025-11-23 17:14:23,694] Trial 134 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:14:31,167] Trial 135 finished with value: 0.6196615501468968 and parameters: {'l1_size': 178, 'l2_size': 78, 'l3_size': 48, 'emb_dropout': 0.4320812215885473, 'hidden_dropout': 0.48867373746990306, 'lr': 0.007612095743278242, 'weight_decay': 4.928524662689897e-05}. Best is trial 117 with value: 0.6339227462617446.
# [I 2025-11-23 17:14:33,586] Trial 136 pruned.
# [I 2025-11-23 17:14:36,005] Trial 137 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:14:43,283] Trial 138 finished with value: 0.6165376811365769 and parameters: {'l1_size': 160, 'l2_size': 170, 'l3_size': 75, 'emb_dropout': 0.4651724902867608, 'hidden_dropout': 0.4814493863559901, 'lr': 0.008225671002690785, 'weight_decay': 3.972674168505348e-05}. Best is trial 117 with value: 0.6339227462617446.
# [I 2025-11-23 17:14:45,860] Trial 139 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:14:53,486] Trial 140 finished with value: 0.6299512428477002 and parameters: {'l1_size': 210, 'l2_size': 93, 'l3_size': 128, 'emb_dropout': 0.4791585066769144, 'hidden_dropout': 0.49448940732269847, 'lr': 0.009954124162034879, 'weight_decay': 7.07915721783958e-05}. Best is trial 117 with value: 0.6339227462617446.
# [I 2025-11-23 17:14:55,913] Trial 141 pruned.
# [I 2025-11-23 17:14:58,274] Trial 142 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:15:05,764] Trial 143 finished with value: 0.6164363952770899 and parameters: {'l1_size': 185, 'l2_size': 72, 'l3_size': 120, 'emb_dropout': 0.4850021476850242, 'hidden_dropout': 0.4649394558859347, 'lr': 0.008393946965211122, 'weight_decay': 4.6960094231735083e-05}. Best is trial 117 with value: 0.6339227462617446.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:15:12,962] Trial 144 finished with value: 0.6197708440363203 and parameters: {'l1_size': 168, 'l2_size': 87, 'l3_size': 72, 'emb_dropout': 0.4527464209962599, 'hidden_dropout': 0.49965293953360795, 'lr': 0.007589241233771075, 'weight_decay': 9.364168487231937e-05}. Best is trial 117 with value: 0.6339227462617446.
# [I 2025-11-23 17:15:15,434] Trial 145 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:15:22,848] Trial 146 finished with value: 0.6135780386073878 and parameters: {'l1_size': 150, 'l2_size': 86, 'l3_size': 72, 'emb_dropout': 0.4261303308832791, 'hidden_dropout': 0.4799191695580167, 'lr': 0.00738000429526686, 'weight_decay': 7.279657900507742e-05}. Best is trial 117 with value: 0.6339227462617446.
# ...
# [I 2025-11-23 17:36:28,573] Trial 505 pruned.
# [I 2025-11-23 17:36:30,959] Trial 506 pruned.
# [I 2025-11-23 17:36:33,386] Trial 507 pruned.
# [I 2025-11-23 17:36:35,900] Trial 508 pruned.
# [I 2025-11-23 17:36:38,302] Trial 509 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:36:45,400] Trial 510 finished with value: 0.6134980296475006 and parameters: {'l1_size': 153, 'l2_size': 69, 'l3_size': 60, 'emb_dropout': 0.4751986762880477, 'hidden_dropout': 0.47589398392096854, 'lr': 0.005110996564610286, 'weight_decay': 2.520314655068706e-05}. Best is trial 193 with value: 0.6418367303169121.
# [I 2025-11-23 17:36:47,736] Trial 511 pruned.
# [I 2025-11-23 17:36:50,125] Trial 512 pruned.
# [I 2025-11-23 17:36:52,459] Trial 513 pruned.
# [I 2025-11-23 17:36:54,870] Trial 514 pruned.
# [I 2025-11-23 17:36:57,232] Trial 515 pruned.
# [I 2025-11-23 17:36:59,539] Trial 516 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:37:06,621] Trial 517 finished with value: 0.6325657063778583 and parameters: {'l1_size': 147, 'l2_size': 80, 'l3_size': 36, 'emb_dropout': 0.49977392416964866, 'hidden_dropout': 0.4834447425896083, 'lr': 0.0056574576001740306, 'weight_decay': 2.773206372148615e-05}. Best is trial 193 with value: 0.6418367303169121.
# [I 2025-11-23 17:37:09,048] Trial 518 pruned.
# [I 2025-11-23 17:37:11,593] Trial 519 pruned.
# [I 2025-11-23 17:37:14,028] Trial 520 pruned.
# [I 2025-11-23 17:37:16,332] Trial 521 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:37:23,285] Trial 522 finished with value: 0.6247453426255346 and parameters: {'l1_size': 168, 'l2_size': 73, 'l3_size': 32, 'emb_dropout': 0.4879883468959589, 'hidden_dropout': 0.4802023496615561, 'lr': 0.006355830859208976, 'weight_decay': 3.1009317730481445e-05}. Best is trial 193 with value: 0.6418367303169121.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:37:30,264] Trial 523 finished with value: 0.6333249213619051 and parameters: {'l1_size': 156, 'l2_size': 83, 'l3_size': 51, 'emb_dropout': 0.4912772095778222, 'hidden_dropout': 0.48583186930118316, 'lr': 0.0071034571288416705, 'weight_decay': 2.7321987670027583e-05}. Best is trial 193 with value: 0.6418367303169121.
# [I 2025-11-23 17:37:32,625] Trial 524 pruned.
# [I 2025-11-23 17:37:35,089] Trial 525 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:37:41,978] Trial 526 finished with value: 0.6311174026427017 and parameters: {'l1_size': 167, 'l2_size': 67, 'l3_size': 34, 'emb_dropout': 0.48979678114061853, 'hidden_dropout': 0.4757547061314264, 'lr': 0.007134845624707696, 'weight_decay': 2.333186228844477e-05}. Best is trial 193 with value: 0.6418367303169121.
# [I 2025-11-23 17:37:44,336] Trial 527 pruned.
# [I 2025-11-23 17:37:46,663] Trial 528 pruned.
# [I 2025-11-23 17:37:48,993] Trial 529 pruned.
# [I 2025-11-23 17:37:51,550] Trial 530 pruned.
# [I 2025-11-23 17:37:53,966] Trial 531 pruned.
# [I 2025-11-23 17:37:56,424] Trial 532 pruned.
# [I 2025-11-23 17:37:58,925] Trial 533 pruned.
# [I 2025-11-23 17:38:01,255] Trial 534 pruned.
# [I 2025-11-23 17:38:03,675] Trial 535 pruned.
# [I 2025-11-23 17:38:06,048] Trial 536 pruned.
# [I 2025-11-23 17:38:08,463] Trial 537 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:38:15,577] Trial 538 finished with value: 0.6224124675988513 and parameters: {'l1_size': 158, 'l2_size': 67, 'l3_size': 53, 'emb_dropout': 0.4998304113333492, 'hidden_dropout': 0.4622352430699261, 'lr': 0.007444180463162215, 'weight_decay': 1.3790640298600592e-05}. Best is trial 193 with value: 0.6418367303169121.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:38:23,092] Trial 539 finished with value: 0.6404222498643732 and parameters: {'l1_size': 170, 'l2_size': 71, 'l3_size': 50, 'emb_dropout': 0.49239165711219757, 'hidden_dropout': 0.4899122207133322, 'lr': 0.007551070063204927, 'weight_decay': 3.12845665580728e-05}. Best is trial 193 with value: 0.6418367303169121.
# [I 2025-11-23 17:38:25,434] Trial 540 pruned.
# [I 2025-11-23 17:38:27,857] Trial 541 pruned.
# [I 2025-11-23 17:38:30,285] Trial 542 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:38:37,431] Trial 543 finished with value: 0.6203805431042515 and parameters: {'l1_size': 166, 'l2_size': 71, 'l3_size': 49, 'emb_dropout': 0.4891999889272674, 'hidden_dropout': 0.4771476400353957, 'lr': 0.006052493594128953, 'weight_decay': 2.7217396826595364e-05}. Best is trial 193 with value: 0.6418367303169121.
# [I 2025-11-23 17:38:39,889] Trial 544 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:38:47,048] Trial 545 finished with value: 0.6391210645753733 and parameters: {'l1_size': 165, 'l2_size': 68, 'l3_size': 50, 'emb_dropout': 0.4841399238865206, 'hidden_dropout': 0.4559102462965352, 'lr': 0.005518833895092432, 'weight_decay': 1.6142591300256777e-05}. Best is trial 193 with value: 0.6418367303169121.
# [I 2025-11-23 17:38:49,391] Trial 546 pruned.
# [I 2025-11-23 17:38:51,751] Trial 547 pruned.
# [I 2025-11-23 17:38:54,146] Trial 548 pruned.
# [I 2025-11-23 17:38:56,563] Trial 549 pruned.
# [I 2025-11-23 17:38:58,928] Trial 550 pruned.
# [I 2025-11-23 17:39:01,354] Trial 551 pruned.
# [I 2025-11-23 17:39:03,730] Trial 552 pruned.
# [I 2025-11-23 17:39:06,076] Trial 553 pruned.
# [I 2025-11-23 17:39:08,436] Trial 554 pruned.
# [I 2025-11-23 17:39:10,795] Trial 555 pruned.
# [I 2025-11-23 17:39:13,142] Trial 556 pruned.
# [I 2025-11-23 17:39:15,500] Trial 557 pruned.
# [I 2025-11-23 17:39:18,037] Trial 558 pruned.
# [I 2025-11-23 17:39:20,397] Trial 559 pruned.
# [I 2025-11-23 17:39:22,740] Trial 560 pruned.
# [I 2025-11-23 17:39:25,322] Trial 561 pruned.
# [I 2025-11-23 17:39:27,714] Trial 562 pruned.
# [I 2025-11-23 17:39:30,061] Trial 563 pruned.
# [I 2025-11-23 17:39:32,384] Trial 564 pruned.
# [I 2025-11-23 17:39:34,715] Trial 565 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:39:43,328] Trial 566 finished with value: 0.6302022455090798 and parameters: {'l1_size': 183, 'l2_size': 64, 'l3_size': 48, 'emb_dropout': 0.4822522326826182, 'hidden_dropout': 0.481069899330831, 'lr': 0.006019247214135852, 'weight_decay': 2.9262404103549965e-05}. Best is trial 193 with value: 0.6418367303169121.
# [I 2025-11-23 17:39:46,438] Trial 567 pruned.
# [I 2025-11-23 17:39:49,605] Trial 568 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:39:58,709] Trial 569 finished with value: 0.6127606185710627 and parameters: {'l1_size': 153, 'l2_size': 134, 'l3_size': 50, 'emb_dropout': 0.47899072338819265, 'hidden_dropout': 0.4708444911976796, 'lr': 0.007954043649700393, 'weight_decay': 3.89347166705672e-05}. Best is trial 193 with value: 0.6418367303169121.
# [I 2025-11-23 17:40:01,847] Trial 570 pruned.
# [I 2025-11-23 17:40:04,977] Trial 571 pruned.
# [I 2025-11-23 17:40:08,098] Trial 572 pruned.
# [I 2025-11-23 17:40:11,324] Trial 573 pruned.
# [I 2025-11-23 17:40:14,591] Trial 574 pruned.
# [I 2025-11-23 17:40:17,851] Trial 575 pruned.
# [I 2025-11-23 17:40:21,100] Trial 576 pruned.
# [I 2025-11-23 17:40:24,481] Trial 577 pruned.
# [I 2025-11-23 17:40:27,709] Trial 578 pruned.
# [I 2025-11-23 17:40:30,984] Trial 579 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:40:40,937] Trial 580 finished with value: 0.6182296241157036 and parameters: {'l1_size': 141, 'l2_size': 68, 'l3_size': 37, 'emb_dropout': 0.49967061029416177, 'hidden_dropout': 0.47533137330925224, 'lr': 0.00697584411777782, 'weight_decay': 3.4738535332664725e-05}. Best is trial 193 with value: 0.6418367303169121.
# [I 2025-11-23 17:40:44,179] Trial 581 pruned.
# [I 2025-11-23 17:40:47,272] Trial 582 pruned.
# [I 2025-11-23 17:40:50,361] Trial 583 pruned.
# [I 2025-11-23 17:40:53,321] Trial 584 pruned.
# [I 2025-11-23 17:40:56,402] Trial 585 pruned.
# [I 2025-11-23 17:40:59,352] Trial 586 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:41:08,346] Trial 587 finished with value: 0.6308982542817244 and parameters: {'l1_size': 156, 'l2_size': 70, 'l3_size': 58, 'emb_dropout': 0.48687024965348724, 'hidden_dropout': 0.4853252998559692, 'lr': 0.007336044998212028, 'weight_decay': 3.309390308018047e-05}. Best is trial 193 with value: 0.6418367303169121.
# [I 2025-11-23 17:41:10,761] Trial 588 pruned.
# [I 2025-11-23 17:41:13,117] Trial 589 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:41:20,144] Trial 590 finished with value: 0.6327192309359707 and parameters: {'l1_size': 146, 'l2_size': 73, 'l3_size': 43, 'emb_dropout': 0.4927965493671381, 'hidden_dropout': 0.4799776394052489, 'lr': 0.006885027362189348, 'weight_decay': 3.2842613393984275e-05}. Best is trial 193 with value: 0.6418367303169121.
# [I 2025-11-23 17:41:22,491] Trial 591 pruned.
# [I 2025-11-23 17:41:24,783] Trial 592 pruned.
# [I 2025-11-23 17:41:27,838] Trial 593 pruned.
# [I 2025-11-23 17:41:30,804] Trial 594 pruned.
# [I 2025-11-23 17:41:34,057] Trial 595 pruned.
# [I 2025-11-23 17:41:36,992] Trial 596 pruned.
# [I 2025-11-23 17:41:39,704] Trial 597 pruned.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:41:46,793] Trial 598 finished with value: 0.620401121020287 and parameters: {'l1_size': 143, 'l2_size': 72, 'l3_size': 46, 'emb_dropout': 0.49313689039878206, 'hidden_dropout': 0.46712385780901955, 'lr': 0.007192404593786529, 'weight_decay': 2.5003151395792297e-05}. Best is trial 193 with value: 0.6418367303169121.
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# C:\Users\hrush\AppData\Roaming\Python\Python311\site-packages\optuna\trial\_trial.py:501: UserWarning: The reported value is ignored because this `step` 0 is already reported.
#   warnings.warn(
# [I 2025-11-23 17:41:53,768] Trial 599 finished with value: 0.6169635959561699 and parameters: {'l1_size': 164, 'l2_size': 64, 'l3_size': 54, 'emb_dropout': 0.4808382095319376, 'hidden_dropout': 0.49213392520685595, 'lr': 0.006035305165924751, 'weight_decay': 3.734671123823833e-05}. Best is trial 193 with value: 0.6418367303169121.
# ✅ BEST PARAMS FOUND:
# {'l1_size': 134, 'l2_size': 75, 'l3_size': 50, 'emb_dropout': 0.49289446498570666, 'hidden_dropout': 0.4668269272592776, 'lr': 0.00865747113810307, 'weight_decay': 4.347274107215308e-05}
#
# --- Retraining Final Model with Best Params (5 Folds) ---
# Fold 1 | Best F1: 0.6718
# Fold 2 | Best F1: 0.6488
# Fold 3 | Best F1: 0.6859
# Fold 4 | Best F1: 0.6549
# Fold 5 | Best F1: 0.6382
#
# 🏆 Final Average F1: 0.6599
# ✅ Saved 'nn_optuna_probs.csv'
# ✅ Saved 'submission_600_nn_optuna.csv'
